# %%
import torch
from ImportFile import *

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/Users/baigm/courses/biye/code/BaiPinns'

# %%
path = cwd + '/Schr_double_1/Setup_12/Retrain_1/TrainedModel/model.pkl'
path
# Out:
# '/Users/baigm/courses/biye/code/BaiPinns/Schr_double_1/Setup_12/Retrain_1/TrainedModel/model.pkl'

# %%
model = torch.load(path)
model
# Out:
# Pinns(
#   (input_layer): Linear(in_features=2, out_features=24, bias=True)
#   (batch_input): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=24, out_features=24, bias=True)
#     (1): Linear(in_features=24, out_features=24, bias=True)
#     (2): Linear(in_features=24, out_features=24, bias=True)
#     (3): Linear(in_features=24, out_features=24, bias=True)
#     (4): Linear(in_features=24, out_features=24, bias=True)
#     (5): Linear(in_features=24, out_features=24, bias=True)
#     (6): Linear(in_features=24, out_features=24, bias=True)
#   )
#   (batch_layers): ModuleList(
#     (0): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#     (2): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#     (3): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#     (4): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#     (5): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#     (6): BatchNorm1d(24, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#   )
#   (output_layer): Linear(in_features=24, out_features=2, bias=True)
#   (activation): Tanh()
# )

# %%
images_path = cwd + "/TestBai"
Ec.plotting(model, images_path, Ec.extrema_values, None)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
